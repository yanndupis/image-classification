# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 2
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 2:
# Image - Min Value: 0 Max Value: 240
# Image - Shape: (32, 32, 3)
# Label - Label Id: 6 Name: frog

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
pixel_depth = 255.0

def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    x_normalized = np.array((x - np.min(x))/(np.max(x)-np.min(x)))
    
    return x_normalized


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %%
features, labels=helper.load_cfar10_batch(cifar10_dataset_folder_path, batch_id=1)

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
num_labels=10

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    x=np.array(x)
    labels = (np.arange(num_labels) == x[:,None]).astype(np.float32)
    return labels


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    x = tf.placeholder(tf.float32, 
                       shape=(None, image_shape[0], 
                              image_shape[1], image_shape[2])
                       ,name='x')
    return  x


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    y = tf.placeholder(tf.float32, 
                       shape=(None,n_classes)
                       ,name='y')
    return y


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    keep_prob=tf.placeholder(tf.float32,name='keep_prob')
    return keep_prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """    
    # TODO: Implement Function
    
    input_shape=x_tensor.get_shape().as_list()
    #Weight and biasis
    weights = tf.Variable(tf.truncated_normal(
      [conv_ksize[0],conv_ksize[1],input_shape[3], conv_num_outputs], stddev=0.1))
    biases = tf.Variable(tf.zeros([conv_num_outputs]))
    
    #Convolution
    conv = tf.nn.conv2d(x_tensor, weights, [1, conv_strides[0], conv_strides[1], 1], padding='SAME')
    #Relu
    hidden = tf.nn.relu(conv + biases)
    #Pooling
    pooled = tf.nn.max_pool(hidden, ksize=[1, pool_ksize[0], pool_ksize[1], 1], 
                            strides=[1, pool_strides[0], pool_strides[1], 1],
                          padding='SAME')
    
    return pooled 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    reshaped = tf.reshape(x_tensor, [-1,shape[1]*shape[2] * shape[3]])
    return reshaped


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    weight = tf.Variable(tf.random_normal([shape[1], num_outputs]))
    biasis = tf.Variable(tf.random_normal([num_outputs]))
    
    fc = tf.reshape(x_tensor, [-1, weight.get_shape().as_list()[0]])
    fc = tf.add(tf.matmul(fc, weight), biasis)
    fc = tf.nn.relu(fc)
    return fc


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    
    shape = x_tensor.get_shape().as_list()
    weights= tf.Variable(tf.random_normal([shape[1], num_outputs]))
    biases = tf.Variable(tf.random_normal([num_outputs]))  
    #Output layer
    out = tf.add(tf.matmul(x_tensor, weights), biases)
    
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv1=conv2d_maxpool(x, 16, conv_ksize=(5,5), conv_strides=(1,1), pool_ksize=(1,1), pool_strides=(2,2))
    conv2=conv2d_maxpool(conv1, 16, conv_ksize=(5,5), conv_strides=(1,1), pool_ksize=(1,1), pool_strides=(2,2))
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flat=flatten(conv2)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fc=fully_conn(flat, 32)
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    out=output(fc, 10)
    
    out_drop=tf.nn.dropout(out,keep_prob)
    
    # TODO: return output
    return out_drop


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    feed_dict = {x : feature_batch, y: label_batch,keep_prob:keep_probability}
    session.run([optimizer], feed_dict=feed_dict)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    feed_dict = {x : feature_batch, y: label_batch,keep_prob:1.0}
    l, predictions=session.run([cost, accuracy], feed_dict=feed_dict)
    print('Loss: {:.2f}'.format(l))
    print('Minibatch accuracy: {:.2f}'.format(predictions))
    valid_accuracy = session.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.0})
    print('Validation accuracy: {:.2f}'.format(valid_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 64
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss: 2.51
# Minibatch accuracy: 0.10
# Validation accuracy: 0.14
# Epoch  2, CIFAR-10 Batch 1:  Loss: 2.31
# Minibatch accuracy: 0.17
# Validation accuracy: 0.16
# Epoch  3, CIFAR-10 Batch 1:  Loss: 2.25
# Minibatch accuracy: 0.15
# Validation accuracy: 0.19
# Epoch  4, CIFAR-10 Batch 1:  Loss: 2.28
# Minibatch accuracy: 0.12
# Validation accuracy: 0.18
# Epoch  5, CIFAR-10 Batch 1:  Loss: 2.19
# Minibatch accuracy: 0.22
# Validation accuracy: 0.20
# Epoch  6, CIFAR-10 Batch 1:  Loss: 2.20
# Minibatch accuracy: 0.17
# Validation accuracy: 0.21
# Epoch  7, CIFAR-10 Batch 1:  Loss: 2.19
# Minibatch accuracy: 0.25
# Validation accuracy: 0.21
# Epoch  8, CIFAR-10 Batch 1:  Loss: 2.21
# Minibatch accuracy: 0.22
# Validation accuracy: 0.21
# Epoch  9, CIFAR-10 Batch 1:  Loss: 2.21
# Minibatch accuracy: 0.17
# Validation accuracy: 0.25
# Epoch 10, CIFAR-10 Batch 1:  Loss: 2.16
# Minibatch accuracy: 0.25
# Validation accuracy: 0.23

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss: 2.59
# Minibatch accuracy: 0.20
# Validation accuracy: 0.13
# Epoch  1, CIFAR-10 Batch 2:  Loss: 2.33
# Minibatch accuracy: 0.22
# Validation accuracy: 0.15
# Epoch  1, CIFAR-10 Batch 3:  Loss: 2.15
# Minibatch accuracy: 0.12
# Validation accuracy: 0.17
# Epoch  1, CIFAR-10 Batch 4:  Loss: 2.14
# Minibatch accuracy: 0.17
# Validation accuracy: 0.20
# Epoch  1, CIFAR-10 Batch 5:  Loss: 2.15
# Minibatch accuracy: 0.28
# Validation accuracy: 0.20
# Epoch  2, CIFAR-10 Batch 1:  Loss: 2.11
# Minibatch accuracy: 0.28
# Validation accuracy: 0.22
# Epoch  2, CIFAR-10 Batch 2:  Loss: 2.10
# Minibatch accuracy: 0.17
# Validation accuracy: 0.24
# Epoch  2, CIFAR-10 Batch 3:  Loss: 2.05
# Minibatch accuracy: 0.17
# Validation accuracy: 0.24
# Epoch  2, CIFAR-10 Batch 4:  Loss: 2.06
# Minibatch accuracy: 0.25
# Validation accuracy: 0.25
# Epoch  2, CIFAR-10 Batch 5:  Loss: 2.09
# Minibatch accuracy: 0.25
# Validation accuracy: 0.26
# Epoch  3, CIFAR-10 Batch 1:  Loss: 2.14
# Minibatch accuracy: 0.30
# Validation accuracy: 0.25
# Epoch  3, CIFAR-10 Batch 2:  Loss: 2.03
# Minibatch accuracy: 0.17
# Validation accuracy: 0.26
# Epoch  3, CIFAR-10 Batch 3:  Loss: 2.06
# Minibatch accuracy: 0.22
# Validation accuracy: 0.26
# Epoch  3, CIFAR-10 Batch 4:  Loss: 2.02
# Minibatch accuracy: 0.32
# Validation accuracy: 0.26
# Epoch  3, CIFAR-10 Batch 5:  Loss: 2.13
# Minibatch accuracy: 0.20
# Validation accuracy: 0.28
# Epoch  4, CIFAR-10 Batch 1:  Loss: 2.06
# Minibatch accuracy: 0.35
# Validation accuracy: 0.29
# Epoch  4, CIFAR-10 Batch 2:  Loss: 1.98
# Minibatch accuracy: 0.25
# Validation accuracy: 0.29
# Epoch  4, CIFAR-10 Batch 3:  Loss: 1.97
# Minibatch accuracy: 0.32
# Validation accuracy: 0.28
# Epoch  4, CIFAR-10 Batch 4:  Loss: 2.01
# Minibatch accuracy: 0.30
# Validation accuracy: 0.29
# Epoch  4, CIFAR-10 Batch 5:  Loss: 2.04
# Minibatch accuracy: 0.25
# Validation accuracy: 0.29
# Epoch  5, CIFAR-10 Batch 1:  Loss: 2.08
# Minibatch accuracy: 0.30
# Validation accuracy: 0.29
# Epoch  5, CIFAR-10 Batch 2:  Loss: 1.93
# Minibatch accuracy: 0.35
# Validation accuracy: 0.30
# Epoch  5, CIFAR-10 Batch 3:  Loss: 1.98
# Minibatch accuracy: 0.20
# Validation accuracy: 0.29
# Epoch  5, CIFAR-10 Batch 4:  Loss: 1.93
# Minibatch accuracy: 0.45
# Validation accuracy: 0.30
# Epoch  5, CIFAR-10 Batch 5:  Loss: 2.02
# Minibatch accuracy: 0.25
# Validation accuracy: 0.31
# Epoch  6, CIFAR-10 Batch 1:  Loss: 2.04
# Minibatch accuracy: 0.30
# Validation accuracy: 0.33
# Epoch  6, CIFAR-10 Batch 2:  Loss: 1.85
# Minibatch accuracy: 0.32
# Validation accuracy: 0.32
# Epoch  6, CIFAR-10 Batch 3:  Loss: 1.91
# Minibatch accuracy: 0.38
# Validation accuracy: 0.31
# Epoch  6, CIFAR-10 Batch 4:  Loss: 1.91
# Minibatch accuracy: 0.32
# Validation accuracy: 0.33
# Epoch  6, CIFAR-10 Batch 5:  Loss: 2.02
# Minibatch accuracy: 0.28
# Validation accuracy: 0.35
# Epoch  7, CIFAR-10 Batch 1:  Loss: 2.04
# Minibatch accuracy: 0.32
# Validation accuracy: 0.33
# Epoch  7, CIFAR-10 Batch 2:  Loss: 1.91
# Minibatch accuracy: 0.38
# Validation accuracy: 0.32
# Epoch  7, CIFAR-10 Batch 3:  Loss: 1.88
# Minibatch accuracy: 0.38
# Validation accuracy: 0.33
# Epoch  7, CIFAR-10 Batch 4:  Loss: 1.91
# Minibatch accuracy: 0.35
# Validation accuracy: 0.33
# Epoch  7, CIFAR-10 Batch 5:  Loss: 1.99
# Minibatch accuracy: 0.25
# Validation accuracy: 0.35
# Epoch  8, CIFAR-10 Batch 1:  Loss: 2.03
# Minibatch accuracy: 0.30
# Validation accuracy: 0.35
# Epoch  8, CIFAR-10 Batch 2:  Loss: 1.90
# Minibatch accuracy: 0.43
# Validation accuracy: 0.35
# Epoch  8, CIFAR-10 Batch 3:  Loss: 1.86
# Minibatch accuracy: 0.28
# Validation accuracy: 0.36
# Epoch  8, CIFAR-10 Batch 4:  Loss: 1.86
# Minibatch accuracy: 0.47
# Validation accuracy: 0.35
# Epoch  8, CIFAR-10 Batch 5:  Loss: 1.99
# Minibatch accuracy: 0.25
# Validation accuracy: 0.35
# Epoch  9, CIFAR-10 Batch 1:  Loss: 1.98
# Minibatch accuracy: 0.38
# Validation accuracy: 0.34
# Epoch  9, CIFAR-10 Batch 2:  Loss: 1.88
# Minibatch accuracy: 0.38
# Validation accuracy: 0.34
# Epoch  9, CIFAR-10 Batch 3:  Loss: 1.84
# Minibatch accuracy: 0.28
# Validation accuracy: 0.37
# Epoch  9, CIFAR-10 Batch 4:  Loss: 1.82
# Minibatch accuracy: 0.47
# Validation accuracy: 0.37
# Epoch  9, CIFAR-10 Batch 5:  Loss: 1.93
# Minibatch accuracy: 0.28
# Validation accuracy: 0.37
# Epoch 10, CIFAR-10 Batch 1:  Loss: 2.01
# Minibatch accuracy: 0.35
# Validation accuracy: 0.35
# Epoch 10, CIFAR-10 Batch 2:  Loss: 1.77
# Minibatch accuracy: 0.47
# Validation accuracy: 0.36
# Epoch 10, CIFAR-10 Batch 3:  Loss: 1.84
# Minibatch accuracy: 0.22
# Validation accuracy: 0.35
# Epoch 10, CIFAR-10 Batch 4:  Loss: 1.78
# Minibatch accuracy: 0.43
# Validation accuracy: 0.37
# Epoch 10, CIFAR-10 Batch 5:  Loss: 1.94
# Minibatch accuracy: 0.25
# Validation accuracy: 0.35
# Epoch 11, CIFAR-10 Batch 1:  Loss: 2.02
# Minibatch accuracy: 0.28
# Validation accuracy: 0.36
# Epoch 11, CIFAR-10 Batch 2:  Loss: 1.76
# Minibatch accuracy: 0.38
# Validation accuracy: 0.36
# Epoch 11, CIFAR-10 Batch 3:  Loss: 1.77
# Minibatch accuracy: 0.30
# Validation accuracy: 0.39
# Epoch 11, CIFAR-10 Batch 4:  Loss: 1.84
# Minibatch accuracy: 0.47
# Validation accuracy: 0.34
# Epoch 11, CIFAR-10 Batch 5:  Loss: 1.98
# Minibatch accuracy: 0.28
# Validation accuracy: 0.35
# Epoch 12, CIFAR-10 Batch 1:  Loss: 1.97
# Minibatch accuracy: 0.28
# Validation accuracy: 0.37
# Epoch 12, CIFAR-10 Batch 2:  Loss: 1.71
# Minibatch accuracy: 0.50
# Validation accuracy: 0.38
# Epoch 12, CIFAR-10 Batch 3:  Loss: 1.77
# Minibatch accuracy: 0.32
# Validation accuracy: 0.38
# Epoch 12, CIFAR-10 Batch 4:  Loss: 1.78
# Minibatch accuracy: 0.47
# Validation accuracy: 0.38
# Epoch 12, CIFAR-10 Batch 5:  Loss: 1.88
# Minibatch accuracy: 0.43
# Validation accuracy: 0.39
# Epoch 13, CIFAR-10 Batch 1:  Loss: 1.95
# Minibatch accuracy: 0.35
# Validation accuracy: 0.39
# Epoch 13, CIFAR-10 Batch 2:  Loss: 1.67
# Minibatch accuracy: 0.55
# Validation accuracy: 0.39
# Epoch 13, CIFAR-10 Batch 3:  Loss: 1.74
# Minibatch accuracy: 0.38
# Validation accuracy: 0.39
# Epoch 13, CIFAR-10 Batch 4:  Loss: 1.80
# Minibatch accuracy: 0.40
# Validation accuracy: 0.37
# Epoch 13, CIFAR-10 Batch 5:  Loss: 1.89
# Minibatch accuracy: 0.32
# Validation accuracy: 0.39
# Epoch 14, CIFAR-10 Batch 1:  Loss: 1.94
# Minibatch accuracy: 0.38
# Validation accuracy: 0.39
# Epoch 14, CIFAR-10 Batch 2:  Loss: 1.67
# Minibatch accuracy: 0.52
# Validation accuracy: 0.40
# Epoch 14, CIFAR-10 Batch 3:  Loss: 1.74
# Minibatch accuracy: 0.32
# Validation accuracy: 0.39
# Epoch 14, CIFAR-10 Batch 4:  Loss: 1.77
# Minibatch accuracy: 0.43
# Validation accuracy: 0.39
# Epoch 14, CIFAR-10 Batch 5:  Loss: 1.89
# Minibatch accuracy: 0.38
# Validation accuracy: 0.38
# Epoch 15, CIFAR-10 Batch 1:  Loss: 1.92
# Minibatch accuracy: 0.30
# Validation accuracy: 0.38
# Epoch 15, CIFAR-10 Batch 2:  Loss: 1.74
# Minibatch accuracy: 0.40
# Validation accuracy: 0.39
# Epoch 15, CIFAR-10 Batch 3:  Loss: 1.67
# Minibatch accuracy: 0.35
# Validation accuracy: 0.39
# Epoch 15, CIFAR-10 Batch 4:  Loss: 1.72
# Minibatch accuracy: 0.45
# Validation accuracy: 0.39
# Epoch 15, CIFAR-10 Batch 5:  Loss: 1.83
# Minibatch accuracy: 0.32
# Validation accuracy: 0.40
# Epoch 16, CIFAR-10 Batch 1:  Loss: 1.90
# Minibatch accuracy: 0.43
# Validation accuracy: 0.40
# Epoch 16, CIFAR-10 Batch 2:  Loss: 1.68
# Minibatch accuracy: 0.45
# Validation accuracy: 0.40
# Epoch 16, CIFAR-10 Batch 3:  Loss: 1.60
# Minibatch accuracy: 0.40
# Validation accuracy: 0.40
# Epoch 16, CIFAR-10 Batch 4:  Loss: 1.73
# Minibatch accuracy: 0.43
# Validation accuracy: 0.41
# Epoch 16, CIFAR-10 Batch 5:  Loss: 1.83
# Minibatch accuracy: 0.40
# Validation accuracy: 0.40
# Epoch 17, CIFAR-10 Batch 1:  Loss: 1.89
# Minibatch accuracy: 0.40
# Validation accuracy: 0.40
# Epoch 17, CIFAR-10 Batch 2:  Loss: 1.73
# Minibatch accuracy: 0.52
# Validation accuracy: 0.41
# Epoch 17, CIFAR-10 Batch 3:  Loss: 1.61
# Minibatch accuracy: 0.45
# Validation accuracy: 0.40
# Epoch 17, CIFAR-10 Batch 4:  Loss: 1.71
# Minibatch accuracy: 0.43
# Validation accuracy: 0.41
# Epoch 17, CIFAR-10 Batch 5:  Loss: 1.81
# Minibatch accuracy: 0.38
# Validation accuracy: 0.42
# Epoch 18, CIFAR-10 Batch 1:  Loss: 1.86
# Minibatch accuracy: 0.40
# Validation accuracy: 0.41
# Epoch 18, CIFAR-10 Batch 2:  Loss: 1.66
# Minibatch accuracy: 0.52
# Validation accuracy: 0.40
# Epoch 18, CIFAR-10 Batch 3:  Loss: 1.66
# Minibatch accuracy: 0.38
# Validation accuracy: 0.41
# Epoch 18, CIFAR-10 Batch 4:  Loss: 1.68
# Minibatch accuracy: 0.43
# Validation accuracy: 0.42
# Epoch 18, CIFAR-10 Batch 5:  Loss: 1.80
# Minibatch accuracy: 0.40
# Validation accuracy: 0.43
# Epoch 19, CIFAR-10 Batch 1:  Loss: 1.86
# Minibatch accuracy: 0.43
# Validation accuracy: 0.42
# Epoch 19, CIFAR-10 Batch 2:  Loss: 1.66
# Minibatch accuracy: 0.57
# Validation accuracy: 0.43
# Epoch 19, CIFAR-10 Batch 3:  Loss: 1.57
# Minibatch accuracy: 0.47
# Validation accuracy: 0.43
# Epoch 19, CIFAR-10 Batch 4:  Loss: 1.69
# Minibatch accuracy: 0.40
# Validation accuracy: 0.41
# Epoch 19, CIFAR-10 Batch 5:  Loss: 1.78
# Minibatch accuracy: 0.40
# Validation accuracy: 0.43
# Epoch 20, CIFAR-10 Batch 1:  Loss: 1.86
# Minibatch accuracy: 0.35
# Validation accuracy: 0.42
# Epoch 20, CIFAR-10 Batch 2:  Loss: 1.67
# Minibatch accuracy: 0.50
# Validation accuracy: 0.43
# Epoch 20, CIFAR-10 Batch 3:  Loss: 1.74
# Minibatch accuracy: 0.35
# Validation accuracy: 0.38
# Epoch 20, CIFAR-10 Batch 4:  Loss: 1.71
# Minibatch accuracy: 0.50
# Validation accuracy: 0.41
# Epoch 20, CIFAR-10 Batch 5:  Loss: 1.80
# Minibatch accuracy: 0.40
# Validation accuracy: 0.41
# Epoch 21, CIFAR-10 Batch 1:  Loss: 1.87
# Minibatch accuracy: 0.40
# Validation accuracy: 0.42
# Epoch 21, CIFAR-10 Batch 2:  Loss: 1.61
# Minibatch accuracy: 0.60
# Validation accuracy: 0.43
# Epoch 21, CIFAR-10 Batch 3:  Loss: 1.57
# Minibatch accuracy: 0.40
# Validation accuracy: 0.44
# Epoch 21, CIFAR-10 Batch 4:  Loss: 1.65
# Minibatch accuracy: 0.43
# Validation accuracy: 0.42
# Epoch 21, CIFAR-10 Batch 5:  Loss: 1.75
# Minibatch accuracy: 0.40
# Validation accuracy: 0.43
# Epoch 22, CIFAR-10 Batch 1:  Loss: 1.88
# Minibatch accuracy: 0.32
# Validation accuracy: 0.40
# Epoch 22, CIFAR-10 Batch 2:  Loss: 1.62
# Minibatch accuracy: 0.60
# Validation accuracy: 0.43
# Epoch 22, CIFAR-10 Batch 3:  Loss: 1.55
# Minibatch accuracy: 0.38
# Validation accuracy: 0.43
# Epoch 22, CIFAR-10 Batch 4:  Loss: 1.65
# Minibatch accuracy: 0.45
# Validation accuracy: 0.43
# Epoch 22, CIFAR-10 Batch 5:  Loss: 1.77
# Minibatch accuracy: 0.43
# Validation accuracy: 0.42
# Epoch 23, CIFAR-10 Batch 1:  Loss: 1.81
# Minibatch accuracy: 0.43
# Validation accuracy: 0.43
# Epoch 23, CIFAR-10 Batch 2:  Loss: 1.68
# Minibatch accuracy: 0.50
# Validation accuracy: 0.44
# Epoch 23, CIFAR-10 Batch 3:  Loss: 1.45
# Minibatch accuracy: 0.60
# Validation accuracy: 0.44
# Epoch 23, CIFAR-10 Batch 4:  Loss: 1.60
# Minibatch accuracy: 0.52
# Validation accuracy: 0.44
# Epoch 23, CIFAR-10 Batch 5:  Loss: 1.71
# Minibatch accuracy: 0.35
# Validation accuracy: 0.43
# Epoch 24, CIFAR-10 Batch 1:  Loss: 1.84
# Minibatch accuracy: 0.40
# Validation accuracy: 0.43
# Epoch 24, CIFAR-10 Batch 2:  Loss: 1.57
# Minibatch accuracy: 0.60
# Validation accuracy: 0.44
# Epoch 24, CIFAR-10 Batch 3:  Loss: 1.51
# Minibatch accuracy: 0.47
# Validation accuracy: 0.44
# Epoch 24, CIFAR-10 Batch 4:  Loss: 1.65
# Minibatch accuracy: 0.47
# Validation accuracy: 0.44
# Epoch 24, CIFAR-10 Batch 5:  Loss: 1.76
# Minibatch accuracy: 0.35
# Validation accuracy: 0.44
# Epoch 25, CIFAR-10 Batch 1:  Loss: 1.80
# Minibatch accuracy: 0.40
# Validation accuracy: 0.45
# Epoch 25, CIFAR-10 Batch 2:  Loss: 1.54
# Minibatch accuracy: 0.50
# Validation accuracy: 0.45
# Epoch 25, CIFAR-10 Batch 3:  Loss: 1.49
# Minibatch accuracy: 0.50
# Validation accuracy: 0.45
# Epoch 25, CIFAR-10 Batch 4:  Loss: 1.58
# Minibatch accuracy: 0.45
# Validation accuracy: 0.44
# Epoch 25, CIFAR-10 Batch 5:  Loss: 1.70
# Minibatch accuracy: 0.40
# Validation accuracy: 0.45
# Epoch 26, CIFAR-10 Batch 1:  Loss: 1.82
# Minibatch accuracy: 0.40
# Validation accuracy: 0.43
# Epoch 26, CIFAR-10 Batch 2:  Loss: 1.60
# Minibatch accuracy: 0.55
# Validation accuracy: 0.45
# Epoch 26, CIFAR-10 Batch 3:  Loss: 1.48
# Minibatch accuracy: 0.50
# Validation accuracy: 0.45
# Epoch 26, CIFAR-10 Batch 4:  Loss: 1.61
# Minibatch accuracy: 0.47
# Validation accuracy: 0.42
# Epoch 26, CIFAR-10 Batch 5:  Loss: 1.69
# Minibatch accuracy: 0.35
# Validation accuracy: 0.44
# Epoch 27, CIFAR-10 Batch 1:  Loss: 1.69
# Minibatch accuracy: 0.47
# Validation accuracy: 0.45
# Epoch 27, CIFAR-10 Batch 2:  Loss: 1.59
# Minibatch accuracy: 0.52
# Validation accuracy: 0.45
# Epoch 27, CIFAR-10 Batch 3:  Loss: 1.45
# Minibatch accuracy: 0.47
# Validation accuracy: 0.45
# Epoch 27, CIFAR-10 Batch 4:  Loss: 1.59
# Minibatch accuracy: 0.55
# Validation accuracy: 0.45
# Epoch 27, CIFAR-10 Batch 5:  Loss: 1.68
# Minibatch accuracy: 0.43
# Validation accuracy: 0.45
# Epoch 28, CIFAR-10 Batch 1:  Loss: 1.73
# Minibatch accuracy: 0.43
# Validation accuracy: 0.46
# Epoch 28, CIFAR-10 Batch 2:  Loss: 1.58
# Minibatch accuracy: 0.55
# Validation accuracy: 0.46
# Epoch 28, CIFAR-10 Batch 3:  Loss: 1.42
# Minibatch accuracy: 0.55
# Validation accuracy: 0.45
# Epoch 28, CIFAR-10 Batch 4:  Loss: 1.55
# Minibatch accuracy: 0.57
# Validation accuracy: 0.45
# Epoch 28, CIFAR-10 Batch 5:  Loss: 1.70
# Minibatch accuracy: 0.40
# Validation accuracy: 0.45
# Epoch 29, CIFAR-10 Batch 1:  Loss: 1.69
# Minibatch accuracy: 0.43
# Validation accuracy: 0.46
# Epoch 29, CIFAR-10 Batch 2:  Loss: 1.52
# Minibatch accuracy: 0.57
# Validation accuracy: 0.44
# Epoch 29, CIFAR-10 Batch 3:  Loss: 1.47
# Minibatch accuracy: 0.52
# Validation accuracy: 0.46
# Epoch 29, CIFAR-10 Batch 4:  Loss: 1.54
# Minibatch accuracy: 0.55
# Validation accuracy: 0.46
# Epoch 29, CIFAR-10 Batch 5:  Loss: 1.67
# Minibatch accuracy: 0.40
# Validation accuracy: 0.46
# Epoch 30, CIFAR-10 Batch 1:  Loss: 1.66
# Minibatch accuracy: 0.43
# Validation accuracy: 0.45
# Epoch 30, CIFAR-10 Batch 2:  Loss: 1.54
# Minibatch accuracy: 0.60
# Validation accuracy: 0.47
# Epoch 30, CIFAR-10 Batch 3:  Loss: 1.43
# Minibatch accuracy: 0.45
# Validation accuracy: 0.46
# Epoch 30, CIFAR-10 Batch 4:  Loss: 1.51
# Minibatch accuracy: 0.55
# Validation accuracy: 0.46
# Epoch 30, CIFAR-10 Batch 5:  Loss: 1.70
# Minibatch accuracy: 0.43
# Validation accuracy: 0.45
# Epoch 31, CIFAR-10 Batch 1:  Loss: 1.70
# Minibatch accuracy: 0.45
# Validation accuracy: 0.45
# Epoch 31, CIFAR-10 Batch 2:  Loss: 1.58
# Minibatch accuracy: 0.52
# Validation accuracy: 0.48
# Epoch 31, CIFAR-10 Batch 3:  Loss: 1.44
# Minibatch accuracy: 0.50
# Validation accuracy: 0.47
# Epoch 31, CIFAR-10 Batch 4:  Loss: 1.47
# Minibatch accuracy: 0.55
# Validation accuracy: 0.47
# Epoch 31, CIFAR-10 Batch 5:  Loss: 1.65
# Minibatch accuracy: 0.40
# Validation accuracy: 0.47
# Epoch 32, CIFAR-10 Batch 1:  Loss: 1.67
# Minibatch accuracy: 0.43
# Validation accuracy: 0.47
# Epoch 32, CIFAR-10 Batch 2:  Loss: 1.55
# Minibatch accuracy: 0.52
# Validation accuracy: 0.47
# Epoch 32, CIFAR-10 Batch 3:  Loss: 1.41
# Minibatch accuracy: 0.62
# Validation accuracy: 0.46
# Epoch 32, CIFAR-10 Batch 4:  Loss: 1.47
# Minibatch accuracy: 0.55
# Validation accuracy: 0.47
# Epoch 32, CIFAR-10 Batch 5:  Loss: 1.59
# Minibatch accuracy: 0.47
# Validation accuracy: 0.47
# Epoch 33, CIFAR-10 Batch 1:  Loss: 1.61
# Minibatch accuracy: 0.45
# Validation accuracy: 0.47
# Epoch 33, CIFAR-10 Batch 2:  Loss: 1.55
# Minibatch accuracy: 0.57
# Validation accuracy: 0.47
# Epoch 33, CIFAR-10 Batch 3:  Loss: 1.46
# Minibatch accuracy: 0.50
# Validation accuracy: 0.46
# Epoch 33, CIFAR-10 Batch 4:  Loss: 1.44
# Minibatch accuracy: 0.57
# Validation accuracy: 0.47
# Epoch 33, CIFAR-10 Batch 5:  Loss: 1.62
# Minibatch accuracy: 0.43
# Validation accuracy: 0.47
# Epoch 34, CIFAR-10 Batch 1:  Loss: 1.68
# Minibatch accuracy: 0.40
# Validation accuracy: 0.47
# Epoch 34, CIFAR-10 Batch 2:  Loss: 1.51
# Minibatch accuracy: 0.52
# Validation accuracy: 0.46
# Epoch 34, CIFAR-10 Batch 3:  Loss: 1.44
# Minibatch accuracy: 0.45
# Validation accuracy: 0.46
# Epoch 34, CIFAR-10 Batch 4:  Loss: 1.38
# Minibatch accuracy: 0.57
# Validation accuracy: 0.48
# Epoch 34, CIFAR-10 Batch 5:  Loss: 1.61
# Minibatch accuracy: 0.45
# Validation accuracy: 0.48
# Epoch 35, CIFAR-10 Batch 1:  Loss: 1.65
# Minibatch accuracy: 0.47
# Validation accuracy: 0.47
# Epoch 35, CIFAR-10 Batch 2:  Loss: 1.51
# Minibatch accuracy: 0.50
# Validation accuracy: 0.47
# Epoch 35, CIFAR-10 Batch 3:  Loss: 1.37
# Minibatch accuracy: 0.60
# Validation accuracy: 0.47
# Epoch 35, CIFAR-10 Batch 4:  Loss: 1.42
# Minibatch accuracy: 0.60
# Validation accuracy: 0.48
# Epoch 35, CIFAR-10 Batch 5:  Loss: 1.59
# Minibatch accuracy: 0.43
# Validation accuracy: 0.46
# Epoch 36, CIFAR-10 Batch 1:  Loss: 1.63
# Minibatch accuracy: 0.45
# Validation accuracy: 0.46
# Epoch 36, CIFAR-10 Batch 2:  Loss: 1.49
# Minibatch accuracy: 0.60
# Validation accuracy: 0.48
# Epoch 36, CIFAR-10 Batch 3:  Loss: 1.35
# Minibatch accuracy: 0.52
# Validation accuracy: 0.48
# Epoch 36, CIFAR-10 Batch 4:  Loss: 1.43
# Minibatch accuracy: 0.60
# Validation accuracy: 0.44
# Epoch 36, CIFAR-10 Batch 5:  Loss: 1.63
# Minibatch accuracy: 0.50
# Validation accuracy: 0.47
# Epoch 37, CIFAR-10 Batch 1:  Loss: 1.60
# Minibatch accuracy: 0.45
# Validation accuracy: 0.48
# Epoch 37, CIFAR-10 Batch 2:  Loss: 1.50
# Minibatch accuracy: 0.50
# Validation accuracy: 0.47
# Epoch 37, CIFAR-10 Batch 3:  Loss: 1.36
# Minibatch accuracy: 0.47
# Validation accuracy: 0.47
# Epoch 37, CIFAR-10 Batch 4:  Loss: 1.45
# Minibatch accuracy: 0.62
# Validation accuracy: 0.46
# Epoch 37, CIFAR-10 Batch 5:  Loss: 1.68
# Minibatch accuracy: 0.35
# Validation accuracy: 0.45
# Epoch 38, CIFAR-10 Batch 1:  Loss: 1.63
# Minibatch accuracy: 0.40
# Validation accuracy: 0.48
# Epoch 38, CIFAR-10 Batch 2:  Loss: 1.53
# Minibatch accuracy: 0.47
# Validation accuracy: 0.47
# Epoch 38, CIFAR-10 Batch 3:  Loss: 1.40
# Minibatch accuracy: 0.47
# Validation accuracy: 0.47
# Epoch 38, CIFAR-10 Batch 4:  Loss: 1.33
# Minibatch accuracy: 0.75
# Validation accuracy: 0.48
# Epoch 38, CIFAR-10 Batch 5:  Loss: 1.57
# Minibatch accuracy: 0.43
# Validation accuracy: 0.47
# Epoch 39, CIFAR-10 Batch 1:  Loss: 1.58
# Minibatch accuracy: 0.43
# Validation accuracy: 0.47
# Epoch 39, CIFAR-10 Batch 2:  Loss: 1.49
# Minibatch accuracy: 0.57
# Validation accuracy: 0.47
# Epoch 39, CIFAR-10 Batch 3:  Loss: 1.32
# Minibatch accuracy: 0.62
# Validation accuracy: 0.47
# Epoch 39, CIFAR-10 Batch 4:  Loss: 1.35
# Minibatch accuracy: 0.70
# Validation accuracy: 0.46
# Epoch 39, CIFAR-10 Batch 5:  Loss: 1.61
# Minibatch accuracy: 0.40
# Validation accuracy: 0.46
# Epoch 40, CIFAR-10 Batch 1:  Loss: 1.60
# Minibatch accuracy: 0.45
# Validation accuracy: 0.47
# Epoch 40, CIFAR-10 Batch 2:  Loss: 1.46
# Minibatch accuracy: 0.57
# Validation accuracy: 0.46
# Epoch 40, CIFAR-10 Batch 3:  Loss: 1.34
# Minibatch accuracy: 0.57
# Validation accuracy: 0.47
# Epoch 40, CIFAR-10 Batch 4:  Loss: 1.41
# Minibatch accuracy: 0.65
# Validation accuracy: 0.48
# Epoch 40, CIFAR-10 Batch 5:  Loss: 1.54
# Minibatch accuracy: 0.47
# Validation accuracy: 0.47
# Epoch 41, CIFAR-10 Batch 1:  Loss: 1.64
# Minibatch accuracy: 0.45
# Validation accuracy: 0.47
# Epoch 41, CIFAR-10 Batch 2:  Loss: 1.43
# Minibatch accuracy: 0.62
# Validation accuracy: 0.47
# Epoch 41, CIFAR-10 Batch 3:  Loss: 1.43
# Minibatch accuracy: 0.57
# Validation accuracy: 0.47
# Epoch 41, CIFAR-10 Batch 4:  Loss: 1.33
# Minibatch accuracy: 0.68
# Validation accuracy: 0.48
# Epoch 41, CIFAR-10 Batch 5:  Loss: 1.55
# Minibatch accuracy: 0.52
# Validation accuracy: 0.48
# Epoch 42, CIFAR-10 Batch 1:  Loss: 1.62
# Minibatch accuracy: 0.40
# Validation accuracy: 0.47
# Epoch 42, CIFAR-10 Batch 2:  Loss: 1.48
# Minibatch accuracy: 0.52
# Validation accuracy: 0.47
# Epoch 42, CIFAR-10 Batch 3:  Loss: 1.38
# Minibatch accuracy: 0.52
# Validation accuracy: 0.47
# Epoch 42, CIFAR-10 Batch 4:  Loss: 1.39
# Minibatch accuracy: 0.65
# Validation accuracy: 0.47
# Epoch 42, CIFAR-10 Batch 5:  Loss: 1.57
# Minibatch accuracy: 0.45
# Validation accuracy: 0.48
# Epoch 43, CIFAR-10 Batch 1:  Loss: 1.55
# Minibatch accuracy: 0.45
# Validation accuracy: 0.48
# Epoch 43, CIFAR-10 Batch 2:  Loss: 1.44
# Minibatch accuracy: 0.57
# Validation accuracy: 0.48
# Epoch 43, CIFAR-10 Batch 3:  Loss: 1.32
# Minibatch accuracy: 0.62
# Validation accuracy: 0.47
# Epoch 43, CIFAR-10 Batch 4:  Loss: 1.36
# Minibatch accuracy: 0.68
# Validation accuracy: 0.48
# Epoch 43, CIFAR-10 Batch 5:  Loss: 1.63
# Minibatch accuracy: 0.45
# Validation accuracy: 0.48
# Epoch 44, CIFAR-10 Batch 1:  Loss: 1.59
# Minibatch accuracy: 0.45
# Validation accuracy: 0.48
# Epoch 44, CIFAR-10 Batch 2:  Loss: 1.38
# Minibatch accuracy: 0.55
# Validation accuracy: 0.47
# Epoch 44, CIFAR-10 Batch 3:  Loss: 1.31
# Minibatch accuracy: 0.68
# Validation accuracy: 0.48
# Epoch 44, CIFAR-10 Batch 4:  Loss: 1.32
# Minibatch accuracy: 0.68
# Validation accuracy: 0.47
# Epoch 44, CIFAR-10 Batch 5:  Loss: 1.54
# Minibatch accuracy: 0.47
# Validation accuracy: 0.46
# Epoch 45, CIFAR-10 Batch 1:  Loss: 1.52
# Minibatch accuracy: 0.47
# Validation accuracy: 0.48
# Epoch 45, CIFAR-10 Batch 2:  Loss: 1.42
# Minibatch accuracy: 0.60
# Validation accuracy: 0.48
# Epoch 45, CIFAR-10 Batch 3:  Loss: 1.32
# Minibatch accuracy: 0.60
# Validation accuracy: 0.49
# Epoch 45, CIFAR-10 Batch 4:  Loss: 1.25
# Minibatch accuracy: 0.68
# Validation accuracy: 0.48
# Epoch 45, CIFAR-10 Batch 5:  Loss: 1.54
# Minibatch accuracy: 0.55
# Validation accuracy: 0.49
# Epoch 46, CIFAR-10 Batch 1:  Loss: 1.56
# Minibatch accuracy: 0.43
# Validation accuracy: 0.49
# Epoch 46, CIFAR-10 Batch 2:  Loss: 1.45
# Minibatch accuracy: 0.52
# Validation accuracy: 0.47
# Epoch 46, CIFAR-10 Batch 3:  Loss: 1.36
# Minibatch accuracy: 0.60
# Validation accuracy: 0.48
# Epoch 46, CIFAR-10 Batch 4:  Loss: 1.31
# Minibatch accuracy: 0.62
# Validation accuracy: 0.48
# Epoch 46, CIFAR-10 Batch 5:  Loss: 1.53
# Minibatch accuracy: 0.43
# Validation accuracy: 0.49
# Epoch 47, CIFAR-10 Batch 1:  Loss: 1.54
# Minibatch accuracy: 0.45
# Validation accuracy: 0.49
# Epoch 47, CIFAR-10 Batch 2:  Loss: 1.39
# Minibatch accuracy: 0.57
# Validation accuracy: 0.48
# Epoch 47, CIFAR-10 Batch 3:  Loss: 1.27
# Minibatch accuracy: 0.70
# Validation accuracy: 0.49
# Epoch 47, CIFAR-10 Batch 4:  Loss: 1.32
# Minibatch accuracy: 0.65
# Validation accuracy: 0.49
# Epoch 47, CIFAR-10 Batch 5:  Loss: 1.56
# Minibatch accuracy: 0.50
# Validation accuracy: 0.48
# Epoch 48, CIFAR-10 Batch 1:  Loss: 1.59
# Minibatch accuracy: 0.40
# Validation accuracy: 0.48
# Epoch 48, CIFAR-10 Batch 2:  Loss: 1.40
# Minibatch accuracy: 0.57
# Validation accuracy: 0.48
# Epoch 48, CIFAR-10 Batch 3:  Loss: 1.31
# Minibatch accuracy: 0.60
# Validation accuracy: 0.49
# Epoch 48, CIFAR-10 Batch 4:  Loss: 1.33
# Minibatch accuracy: 0.62
# Validation accuracy: 0.48
# Epoch 48, CIFAR-10 Batch 5:  Loss: 1.50
# Minibatch accuracy: 0.50
# Validation accuracy: 0.48
# Epoch 49, CIFAR-10 Batch 1:  Loss: 1.56
# Minibatch accuracy: 0.43
# Validation accuracy: 0.48
# Epoch 49, CIFAR-10 Batch 2:  Loss: 1.37
# Minibatch accuracy: 0.57
# Validation accuracy: 0.48
# Epoch 49, CIFAR-10 Batch 3:  Loss: 1.30
# Minibatch accuracy: 0.52
# Validation accuracy: 0.48
# Epoch 49, CIFAR-10 Batch 4:  Loss: 1.28
# Minibatch accuracy: 0.65
# Validation accuracy: 0.48
# Epoch 49, CIFAR-10 Batch 5:  Loss: 1.51
# Minibatch accuracy: 0.52
# Validation accuracy: 0.48
# Epoch 50, CIFAR-10 Batch 1:  Loss: 1.57
# Minibatch accuracy: 0.47
# Validation accuracy: 0.49
# Epoch 50, CIFAR-10 Batch 2:  Loss: 1.37
# Minibatch accuracy: 0.60
# Validation accuracy: 0.47
# Epoch 50, CIFAR-10 Batch 3:  Loss: 1.31
# Minibatch accuracy: 0.57
# Validation accuracy: 0.48
# Epoch 50, CIFAR-10 Batch 4:  Loss: 1.36
# Minibatch accuracy: 0.68
# Validation accuracy: 0.48
# Epoch 50, CIFAR-10 Batch 5:  Loss: 1.47
# Minibatch accuracy: 0.52
# Validation accuracy: 0.49
# Epoch 51, CIFAR-10 Batch 1:  Loss: 1.48
# Minibatch accuracy: 0.50
# Validation accuracy: 0.49
# Epoch 51, CIFAR-10 Batch 2:  Loss: 1.36
# Minibatch accuracy: 0.62
# Validation accuracy: 0.48
# Epoch 51, CIFAR-10 Batch 3:  Loss: 1.31
# Minibatch accuracy: 0.52
# Validation accuracy: 0.47
# Epoch 51, CIFAR-10 Batch 4:  Loss: 1.27
# Minibatch accuracy: 0.68
# Validation accuracy: 0.48
# Epoch 51, CIFAR-10 Batch 5:  Loss: 1.50
# Minibatch accuracy: 0.47
# Validation accuracy: 0.49
# Epoch 52, CIFAR-10 Batch 1:  Loss: 1.50
# Minibatch accuracy: 0.50
# Validation accuracy: 0.49
# Epoch 52, CIFAR-10 Batch 2:  Loss: 1.34
# Minibatch accuracy: 0.65
# Validation accuracy: 0.49
# Epoch 52, CIFAR-10 Batch 3:  Loss: 1.30
# Minibatch accuracy: 0.60
# Validation accuracy: 0.50
# Epoch 52, CIFAR-10 Batch 4:  Loss: 1.22
# Minibatch accuracy: 0.68
# Validation accuracy: 0.49
# Epoch 52, CIFAR-10 Batch 5:  Loss: 1.55
# Minibatch accuracy: 0.52
# Validation accuracy: 0.48
# Epoch 53, CIFAR-10 Batch 1:  Loss: 1.48
# Minibatch accuracy: 0.50
# Validation accuracy: 0.49
# Epoch 53, CIFAR-10 Batch 2:  Loss: 1.40
# Minibatch accuracy: 0.60
# Validation accuracy: 0.48
# Epoch 53, CIFAR-10 Batch 3:  Loss: 1.33
# Minibatch accuracy: 0.62
# Validation accuracy: 0.47
# Epoch 53, CIFAR-10 Batch 4:  Loss: 1.29
# Minibatch accuracy: 0.60
# Validation accuracy: 0.49
# Epoch 53, CIFAR-10 Batch 5:  Loss: 1.52
# Minibatch accuracy: 0.50
# Validation accuracy: 0.50
# Epoch 54, CIFAR-10 Batch 1:  Loss: 1.52
# Minibatch accuracy: 0.45
# Validation accuracy: 0.48
# Epoch 54, CIFAR-10 Batch 2:  Loss: 1.35
# Minibatch accuracy: 0.65
# Validation accuracy: 0.48
# Epoch 54, CIFAR-10 Batch 3:  Loss: 1.29
# Minibatch accuracy: 0.65
# Validation accuracy: 0.48
# Epoch 54, CIFAR-10 Batch 4:  Loss: 1.31
# Minibatch accuracy: 0.60
# Validation accuracy: 0.47
# Epoch 54, CIFAR-10 Batch 5:  Loss: 1.53
# Minibatch accuracy: 0.45
# Validation accuracy: 0.49
# Epoch 55, CIFAR-10 Batch 1:  Loss: 1.45
# Minibatch accuracy: 0.57
# Validation accuracy: 0.49
# Epoch 55, CIFAR-10 Batch 2:  Loss: 1.32
# Minibatch accuracy: 0.60
# Validation accuracy: 0.48
# Epoch 55, CIFAR-10 Batch 3:  Loss: 1.29
# Minibatch accuracy: 0.60
# Validation accuracy: 0.49
# Epoch 55, CIFAR-10 Batch 4:  Loss: 1.26
# Minibatch accuracy: 0.68
# Validation accuracy: 0.48
# Epoch 55, CIFAR-10 Batch 5:  Loss: 1.49
# Minibatch accuracy: 0.47
# Validation accuracy: 0.48
# Epoch 56, CIFAR-10 Batch 1:  Loss: 1.49
# Minibatch accuracy: 0.47
# Validation accuracy: 0.50
# Epoch 56, CIFAR-10 Batch 2:  Loss: 1.33
# Minibatch accuracy: 0.55
# Validation accuracy: 0.49
# Epoch 56, CIFAR-10 Batch 3:  Loss: 1.29
# Minibatch accuracy: 0.52
# Validation accuracy: 0.49
# Epoch 56, CIFAR-10 Batch 4:  Loss: 1.30
# Minibatch accuracy: 0.60
# Validation accuracy: 0.48
# Epoch 56, CIFAR-10 Batch 5:  Loss: 1.46
# Minibatch accuracy: 0.52
# Validation accuracy: 0.49
# Epoch 57, CIFAR-10 Batch 1:  Loss: 1.50
# Minibatch accuracy: 0.50
# Validation accuracy: 0.48
# Epoch 57, CIFAR-10 Batch 2:  Loss: 1.31
# Minibatch accuracy: 0.62
# Validation accuracy: 0.48
# Epoch 57, CIFAR-10 Batch 3:  Loss: 1.30
# Minibatch accuracy: 0.65
# Validation accuracy: 0.50
# Epoch 57, CIFAR-10 Batch 4:  Loss: 1.30
# Minibatch accuracy: 0.62
# Validation accuracy: 0.48
# Epoch 57, CIFAR-10 Batch 5:  Loss: 1.49
# Minibatch accuracy: 0.47
# Validation accuracy: 0.50
# Epoch 58, CIFAR-10 Batch 1:  Loss: 1.51
# Minibatch accuracy: 0.43
# Validation accuracy: 0.49
# Epoch 58, CIFAR-10 Batch 2:  Loss: 1.32
# Minibatch accuracy: 0.62
# Validation accuracy: 0.48
# Epoch 58, CIFAR-10 Batch 3:  Loss: 1.25
# Minibatch accuracy: 0.60
# Validation accuracy: 0.50
# Epoch 58, CIFAR-10 Batch 4:  Loss: 1.22
# Minibatch accuracy: 0.70
# Validation accuracy: 0.49
# Epoch 58, CIFAR-10 Batch 5:  Loss: 1.51
# Minibatch accuracy: 0.50
# Validation accuracy: 0.49
# Epoch 59, CIFAR-10 Batch 1:  Loss: 1.52
# Minibatch accuracy: 0.43
# Validation accuracy: 0.48
# Epoch 59, CIFAR-10 Batch 2:  Loss: 1.40
# Minibatch accuracy: 0.65
# Validation accuracy: 0.49
# Epoch 59, CIFAR-10 Batch 3:  Loss: 1.31
# Minibatch accuracy: 0.60
# Validation accuracy: 0.49
# Epoch 59, CIFAR-10 Batch 4:  Loss: 1.20
# Minibatch accuracy: 0.62
# Validation accuracy: 0.49
# Epoch 59, CIFAR-10 Batch 5:  Loss: 1.44
# Minibatch accuracy: 0.47
# Epoch 62, CIFAR-10 Batch 2:  Loss: 1.33
# Minibatch accuracy: 0.60
# Validation accuracy: 0.49
# Epoch 62, CIFAR-10 Batch 3:  Loss: 1.26
# Minibatch accuracy: 0.62
# Validation accuracy: 0.50
# Epoch 62, CIFAR-10 Batch 4:  Loss: 1.20
# Minibatch accuracy: 0.68
# Validation accuracy: 0.48
# Epoch 62, CIFAR-10 Batch 5:  Loss: 1.42
# Minibatch accuracy: 0.50
# Validation accuracy: 0.49
# Epoch 63, CIFAR-10 Batch 1:  Loss: 1.45
# Minibatch accuracy: 0.50
# Validation accuracy: 0.49
# Epoch 63, CIFAR-10 Batch 2:  Loss: 1.32
# Minibatch accuracy: 0.65
# Validation accuracy: 0.48
# Epoch 63, CIFAR-10 Batch 3:  Loss: 1.27
# Minibatch accuracy: 0.55
# Validation accuracy: 0.50
# Epoch 63, CIFAR-10 Batch 4:  Loss: 1.19
# Minibatch accuracy: 0.65
# Validation accuracy: 0.48
# Epoch 63, CIFAR-10 Batch 5:  Loss: 1.48
# Minibatch accuracy: 0.52
# Validation accuracy: 0.49
# Epoch 64, CIFAR-10 Batch 1:  Loss: 1.52
# Minibatch accuracy: 0.45
# Validation accuracy: 0.49
# Epoch 64, CIFAR-10 Batch 2:  Loss: 1.26
# Minibatch accuracy: 0.62
# Validation accuracy: 0.49
# Epoch 64, CIFAR-10 Batch 3:  Loss: 1.32
# Minibatch accuracy: 0.50
# Validation accuracy: 0.49
# Epoch 64, CIFAR-10 Batch 4:  Loss: 1.22
# Minibatch accuracy: 0.65
# Validation accuracy: 0.48
# Epoch 64, CIFAR-10 Batch 5:  Loss: 1.43
# Minibatch accuracy: 0.57
# Validation accuracy: 0.50
# Epoch 65, CIFAR-10 Batch 1:  Loss: 1.42
# Minibatch accuracy: 0.52
# Validation accuracy: 0.50
# Epoch 65, CIFAR-10 Batch 2:  Loss: 1.32
# Minibatch accuracy: 0.60
# Validation accuracy: 0.49
# Epoch 65, CIFAR-10 Batch 3:  Loss: 1.29
# Minibatch accuracy: 0.62
# Validation accuracy: 0.50
# Epoch 65, CIFAR-10 Batch 4:  Loss: 1.27
# Minibatch accuracy: 0.60
# Validation accuracy: 0.49
# Epoch 65, CIFAR-10 Batch 5:  Loss: 1.44
# Minibatch accuracy: 0.50
# Validation accuracy: 0.49
# Epoch 66, CIFAR-10 Batch 1:  Loss: 1.40
# Minibatch accuracy: 0.55
# Validation accuracy: 0.50
# Epoch 66, CIFAR-10 Batch 2:  Loss: 1.27
# Minibatch accuracy: 0.65
# Validation accuracy: 0.49
# Epoch 66, CIFAR-10 Batch 3:  Loss: 1.24
# Minibatch accuracy: 0.60
# Validation accuracy: 0.49
# Epoch 66, CIFAR-10 Batch 4:  Loss: 1.25
# Minibatch accuracy: 0.68
# Validation accuracy: 0.50
# Epoch 66, CIFAR-10 Batch 5:  Loss: 1.44
# Minibatch accuracy: 0.50
# Validation accuracy: 0.50
# Epoch 67, CIFAR-10 Batch 1:  Loss: 1.41
# Minibatch accuracy: 0.45
# Validation accuracy: 0.49
# Epoch 67, CIFAR-10 Batch 2:  Loss: 1.22
# Minibatch accuracy: 0.60
# Validation accuracy: 0.49
# Epoch 67, CIFAR-10 Batch 3:  Loss: 1.26
# Minibatch accuracy: 0.52
# Validation accuracy: 0.49
# Epoch 67, CIFAR-10 Batch 4:  Loss: 1.22
# Minibatch accuracy: 0.62
# Validation accuracy: 0.50
# Epoch 67, CIFAR-10 Batch 5:  Loss: 1.39
# Minibatch accuracy: 0.47
# Validation accuracy: 0.50
# Epoch 68, CIFAR-10 Batch 1:  Loss: 1.41
# Minibatch accuracy: 0.50
# Validation accuracy: 0.50
# Epoch 68, CIFAR-10 Batch 2:  Loss: 1.29
# Minibatch accuracy: 0.62
# Validation accuracy: 0.50
# Epoch 68, CIFAR-10 Batch 3:  Loss: 1.27
# Minibatch accuracy: 0.60
# Validation accuracy: 0.50
# Epoch 68, CIFAR-10 Batch 4:  Loss: 1.22
# Minibatch accuracy: 0.62
# Validation accuracy: 0.50
# Epoch 68, CIFAR-10 Batch 5:  Loss: 1.38
# Minibatch accuracy: 0.57
# Validation accuracy: 0.49
# Epoch 69, CIFAR-10 Batch 1:  Loss: 1.38
# Minibatch accuracy: 0.47
# Validation accuracy: 0.50
# Epoch 69, CIFAR-10 Batch 2:  Loss: 1.25
# Minibatch accuracy: 0.62
# Validation accuracy: 0.48
# Epoch 69, CIFAR-10 Batch 3:  Loss: 1.28
# Minibatch accuracy: 0.62
# Validation accuracy: 0.50
# Epoch 69, CIFAR-10 Batch 4:  Loss: 1.21
# Minibatch accuracy: 0.65
# Validation accuracy: 0.49
# Epoch 69, CIFAR-10 Batch 5:  Loss: 1.41
# Minibatch accuracy: 0.52
# Validation accuracy: 0.50
# Epoch 70, CIFAR-10 Batch 1:  Loss: 1.44
# Minibatch accuracy: 0.50
# Validation accuracy: 0.49
# Epoch 70, CIFAR-10 Batch 2:  Loss: 1.27
# Minibatch accuracy: 0.60
# Validation accuracy: 0.49
# Epoch 70, CIFAR-10 Batch 3:  Loss: 1.28
# Minibatch accuracy: 0.55
# Validation accuracy: 0.49
# Epoch 70, CIFAR-10 Batch 4:  Loss: 1.16
# Minibatch accuracy: 0.70
# Validation accuracy: 0.49
# Epoch 70, CIFAR-10 Batch 5:  Loss: 1.40
# Minibatch accuracy: 0.45
# Validation accuracy: 0.50
# Epoch 71, CIFAR-10 Batch 1:  Loss: 1.34
# Minibatch accuracy: 0.57
# Validation accuracy: 0.49
# Epoch 71, CIFAR-10 Batch 2:  Loss: 1.29
# Minibatch accuracy: 0.57
# Validation accuracy: 0.49
# Epoch 71, CIFAR-10 Batch 3:  Loss: 1.24
# Minibatch accuracy: 0.60
# Validation accuracy: 0.50
# Epoch 71, CIFAR-10 Batch 4:  Loss: 1.23
# Minibatch accuracy: 0.62
# Validation accuracy: 0.50
# Epoch 71, CIFAR-10 Batch 5:  Loss: 1.36
# Minibatch accuracy: 0.52
# Validation accuracy: 0.49
# Epoch 72, CIFAR-10 Batch 1:  Loss: 1.42
# Minibatch accuracy: 0.47
# Validation accuracy: 0.49
# Epoch 72, CIFAR-10 Batch 2:  Loss: 1.27
# Minibatch accuracy: 0.57
# Validation accuracy: 0.49
# Epoch 72, CIFAR-10 Batch 3:  Loss: 1.27
# Minibatch accuracy: 0.55
# Validation accuracy: 0.50
# Epoch 72, CIFAR-10 Batch 4:  Loss: 1.10
# Minibatch accuracy: 0.65
# Validation accuracy: 0.49
# Epoch 72, CIFAR-10 Batch 5:  Loss: 1.36
# Minibatch accuracy: 0.60
# Validation accuracy: 0.49
# Epoch 73, CIFAR-10 Batch 1:  Loss: 1.41
# Minibatch accuracy: 0.50
# Validation accuracy: 0.50
# Epoch 73, CIFAR-10 Batch 2:  Loss: 1.24
# Minibatch accuracy: 0.73
# Validation accuracy: 0.49
# Epoch 73, CIFAR-10 Batch 3:  Loss: 1.24
# Minibatch accuracy: 0.65
# Validation accuracy: 0.50
# Epoch 73, CIFAR-10 Batch 4:  Loss: 1.26
# Minibatch accuracy: 0.52
# Validation accuracy: 0.49
# Epoch 73, CIFAR-10 Batch 5:  Loss: 1.37
# Minibatch accuracy: 0.50
# Validation accuracy: 0.49
# Epoch 74, CIFAR-10 Batch 1:  Loss: 1.29
# Minibatch accuracy: 0.52
# Validation accuracy: 0.51
# Epoch 74, CIFAR-10 Batch 2:  Loss: 1.20
# Minibatch accuracy: 0.65
# Validation accuracy: 0.50
# Epoch 74, CIFAR-10 Batch 3:  Loss: 1.23
# Minibatch accuracy: 0.55
# Validation accuracy: 0.50
# Epoch 74, CIFAR-10 Batch 4:  Loss: 1.19
# Minibatch accuracy: 0.65
# Validation accuracy: 0.50
# Epoch 74, CIFAR-10 Batch 5:  Loss: 1.40
# Minibatch accuracy: 0.55
# Validation accuracy: 0.50
# Epoch 75, CIFAR-10 Batch 1:  Loss: 1.39
# Minibatch accuracy: 0.50
# Validation accuracy: 0.50
# Epoch 75, CIFAR-10 Batch 2:  Loss: 1.17
# Minibatch accuracy: 0.65
# Validation accuracy: 0.49
# Epoch 75, CIFAR-10 Batch 3:  Loss: 1.24
# Minibatch accuracy: 0.52
# Validation accuracy: 0.50
# Epoch 75, CIFAR-10 Batch 4:  Loss: 1.12
# Minibatch accuracy: 0.65
# Validation accuracy: 0.50
# Epoch 75, CIFAR-10 Batch 5:  Loss: 1.36
# Minibatch accuracy: 0.60
# Validation accuracy: 0.49
# Epoch 76, CIFAR-10 Batch 1:  Loss: 1.39
# Minibatch accuracy: 0.45
# Validation accuracy: 0.50
# Epoch 76, CIFAR-10 Batch 2:  Loss: 1.26
# Minibatch accuracy: 0.57
# Validation accuracy: 0.49
# Epoch 76, CIFAR-10 Batch 3:  Loss: 1.25
# Minibatch accuracy: 0.62
# Validation accuracy: 0.50
# Epoch 76, CIFAR-10 Batch 4:  Loss: 1.16
# Minibatch accuracy: 0.65
# Validation accuracy: 0.49
# Epoch 76, CIFAR-10 Batch 5:  Loss: 1.37
# Minibatch accuracy: 0.52
# Validation accuracy: 0.50
# Epoch 77, CIFAR-10 Batch 1:  Loss: 1.38
# Minibatch accuracy: 0.55
# Validation accuracy: 0.50
# Epoch 77, CIFAR-10 Batch 2:  Loss: 1.24
# Minibatch accuracy: 0.62
# Validation accuracy: 0.50
# Epoch 77, CIFAR-10 Batch 3:  Loss: 1.21
# Minibatch accuracy: 0.62
# Validation accuracy: 0.50
# Epoch 77, CIFAR-10 Batch 4:  Loss: 1.07
# Minibatch accuracy: 0.70
# Validation accuracy: 0.50
# Epoch 77, CIFAR-10 Batch 5:  Loss: 1.41
# Minibatch accuracy: 0.52
# Validation accuracy: 0.49
# Epoch 78, CIFAR-10 Batch 1:  Loss: 1.39
# Minibatch accuracy: 0.52
# Validation accuracy: 0.50
# Epoch 78, CIFAR-10 Batch 2:  Loss: 1.25
# Minibatch accuracy: 0.60
# Validation accuracy: 0.49
# Epoch 78, CIFAR-10 Batch 3:  Loss: 1.23
# Minibatch accuracy: 0.62
# Validation accuracy: 0.50
# Epoch 78, CIFAR-10 Batch 4:  Loss: 1.10
# Minibatch accuracy: 0.68
# Validation accuracy: 0.51
# Epoch 78, CIFAR-10 Batch 5:  Loss: 1.36
# Minibatch accuracy: 0.55
# Validation accuracy: 0.50
# Epoch 79, CIFAR-10 Batch 1:  Loss: 1.29
# Minibatch accuracy: 0.52
# Validation accuracy: 0.50
# Epoch 79, CIFAR-10 Batch 2:  Loss: 1.20
# Minibatch accuracy: 0.57
# Validation accuracy: 0.50
# Epoch 79, CIFAR-10 Batch 3:  Loss: 1.17
# Minibatch accuracy: 0.73
# Validation accuracy: 0.50
# Epoch 79, CIFAR-10 Batch 4:  Loss: 1.10
# Minibatch accuracy: 0.62
# Validation accuracy: 0.50
# Epoch 79, CIFAR-10 Batch 5:  Loss: 1.33
# Minibatch accuracy: 0.60
# Validation accuracy: 0.50
# Epoch 80, CIFAR-10 Batch 1:  Loss: 1.24
# Minibatch accuracy: 0.55
# Validation accuracy: 0.50
# Epoch 80, CIFAR-10 Batch 2:  Loss: 1.24
# Minibatch accuracy: 0.60
# Validation accuracy: 0.50
# Epoch 80, CIFAR-10 Batch 3:  Loss: 1.23
# Minibatch accuracy: 0.62
# Validation accuracy: 0.49
# Epoch 80, CIFAR-10 Batch 4:  Loss: 1.10
# Minibatch accuracy: 0.68
# Validation accuracy: 0.50
# Epoch 80, CIFAR-10 Batch 5:  Loss: 1.35
# Minibatch accuracy: 0.50
# Validation accuracy: 0.49
# Epoch 81, CIFAR-10 Batch 1:  Loss: 1.29
# Minibatch accuracy: 0.52
# Validation accuracy: 0.51
# Epoch 81, CIFAR-10 Batch 2:  Loss: 1.21
# Minibatch accuracy: 0.62
# Validation accuracy: 0.50
# Epoch 81, CIFAR-10 Batch 3:  Loss: 1.17
# Minibatch accuracy: 0.65
# Validation accuracy: 0.51
# Epoch 81, CIFAR-10 Batch 4:  Loss: 1.11
# Minibatch accuracy: 0.70
# Validation accuracy: 0.49
# Epoch 81, CIFAR-10 Batch 5:  Loss: 1.31
# Minibatch accuracy: 0.50
# Validation accuracy: 0.51
# Epoch 82, CIFAR-10 Batch 1:  Loss: 1.35
# Minibatch accuracy: 0.43
# Validation accuracy: 0.50
# Epoch 82, CIFAR-10 Batch 2:  Loss: 1.20
# Minibatch accuracy: 0.62
# Validation accuracy: 0.49
# Epoch 82, CIFAR-10 Batch 3:  Loss: 1.26
# Minibatch accuracy: 0.55
# Validation accuracy: 0.49
# Epoch 82, CIFAR-10 Batch 4:  Loss: 1.17
# Minibatch accuracy: 0.73
# Validation accuracy: 0.49
# Epoch 82, CIFAR-10 Batch 5:  Loss: 1.37
# Minibatch accuracy: 0.57
# Validation accuracy: 0.50
# Epoch 83, CIFAR-10 Batch 1:  Loss: 1.30
# Minibatch accuracy: 0.55
# Validation accuracy: 0.51
# Epoch 83, CIFAR-10 Batch 2:  Loss: 1.21
# Minibatch accuracy: 0.60
# Validation accuracy: 0.49
# Epoch 83, CIFAR-10 Batch 3:  Loss: 1.17
# Minibatch accuracy: 0.68
# Validation accuracy: 0.51
# Epoch 83, CIFAR-10 Batch 4:  Loss: 1.07
# Minibatch accuracy: 0.75
# Validation accuracy: 0.50
# Epoch 83, CIFAR-10 Batch 5:  Loss: 1.33
# Minibatch accuracy: 0.52
# Validation accuracy: 0.50
# Epoch 84, CIFAR-10 Batch 1:  Loss: 1.26
# Minibatch accuracy: 0.55
# Validation accuracy: 0.51
# Epoch 84, CIFAR-10 Batch 2:  Loss: 1.21
# Minibatch accuracy: 0.57
# Validation accuracy: 0.49
# Epoch 84, CIFAR-10 Batch 3:  Loss: 1.18
# Minibatch accuracy: 0.65
# Validation accuracy: 0.50
# Epoch 84, CIFAR-10 Batch 4:  Loss: 1.11
# Minibatch accuracy: 0.70
# Validation accuracy: 0.50
# Epoch 84, CIFAR-10 Batch 5:  Loss: 1.31
# Minibatch accuracy: 0.52
# Validation accuracy: 0.50
# Epoch 85, CIFAR-10 Batch 1:  Loss: 1.28
# Minibatch accuracy: 0.55
# Validation accuracy: 0.50
# Epoch 85, CIFAR-10 Batch 2:  Loss: 1.18
# Minibatch accuracy: 0.60
# Validation accuracy: 0.50
# Epoch 85, CIFAR-10 Batch 3:  Loss: 1.22
# Minibatch accuracy: 0.60
# Validation accuracy: 0.51
# Epoch 85, CIFAR-10 Batch 4:  Loss: 1.12
# Minibatch accuracy: 0.65
# Validation accuracy: 0.50
# Epoch 85, CIFAR-10 Batch 5:  Loss: 1.32
# Minibatch accuracy: 0.52
# Validation accuracy: 0.51
# Epoch 86, CIFAR-10 Batch 1:  Loss: 1.28
# Minibatch accuracy: 0.52
# Validation accuracy: 0.51
# Epoch 86, CIFAR-10 Batch 2:  Loss: 1.20
# Minibatch accuracy: 0.60
# Validation accuracy: 0.50
# Epoch 86, CIFAR-10 Batch 3:  Loss: 1.17
# Minibatch accuracy: 0.62
# Validation accuracy: 0.50
# Epoch 86, CIFAR-10 Batch 4:  Loss: 1.09
# Minibatch accuracy: 0.73
# Validation accuracy: 0.51
# Epoch 86, CIFAR-10 Batch 5:  Loss: 1.36
# Minibatch accuracy: 0.55
# Validation accuracy: 0.51
# Epoch 87, CIFAR-10 Batch 1:  Loss: 1.30
# Minibatch accuracy: 0.55
# Validation accuracy: 0.50
# Epoch 87, CIFAR-10 Batch 2:  Loss: 1.22
# Minibatch accuracy: 0.60
# Validation accuracy: 0.51
# Epoch 87, CIFAR-10 Batch 3:  Loss: 1.15
# Minibatch accuracy: 0.70
# Validation accuracy: 0.51
# Epoch 87, CIFAR-10 Batch 4:  Loss: 1.08
# Minibatch accuracy: 0.70
# Validation accuracy: 0.51
# Epoch 87, CIFAR-10 Batch 5:  Loss: 1.34
# Minibatch accuracy: 0.55
# Validation accuracy: 0.51
# Epoch 88, CIFAR-10 Batch 1:  Loss: 1.29
# Minibatch accuracy: 0.55
# Validation accuracy: 0.50
# Epoch 88, CIFAR-10 Batch 2:  Loss: 1.21
# Minibatch accuracy: 0.60
# Validation accuracy: 0.49
# Epoch 88, CIFAR-10 Batch 3:  Loss: 1.14
# Minibatch accuracy: 0.60
# Validation accuracy: 0.51
# Epoch 88, CIFAR-10 Batch 4:  Loss: 1.03
# Minibatch accuracy: 0.73
# Validation accuracy: 0.51
# Epoch 88, CIFAR-10 Batch 5:  Loss: 1.33
# Minibatch accuracy: 0.57
# Validation accuracy: 0.50
# Epoch 89, CIFAR-10 Batch 1:  Loss: 1.28
# Minibatch accuracy: 0.57
# Validation accuracy: 0.50
# Epoch 89, CIFAR-10 Batch 2:  Loss: 1.19
# Minibatch accuracy: 0.55
# Validation accuracy: 0.47
# Epoch 89, CIFAR-10 Batch 3:  Loss: 1.19
# Minibatch accuracy: 0.62
# Validation accuracy: 0.51
# Epoch 89, CIFAR-10 Batch 4:  Loss: 1.05
# Minibatch accuracy: 0.75
# Validation accuracy: 0.51
# Epoch 89, CIFAR-10 Batch 5:  Loss: 1.30
# Minibatch accuracy: 0.55
# Validation accuracy: 0.50
# Epoch 90, CIFAR-10 Batch 1:  Loss: 1.23
# Minibatch accuracy: 0.60
# Validation accuracy: 0.51
# Epoch 90, CIFAR-10 Batch 2:  Loss: 1.24
# Minibatch accuracy: 0.62
# Validation accuracy: 0.49
# Epoch 90, CIFAR-10 Batch 3:  Loss: 1.14
# Minibatch accuracy: 0.73
# Validation accuracy: 0.52
# Epoch 90, CIFAR-10 Batch 4:  Loss: 1.03
# Minibatch accuracy: 0.77
# Validation accuracy: 0.51
# Epoch 90, CIFAR-10 Batch 5:  Loss: 1.36
# Minibatch accuracy: 0.55
# Validation accuracy: 0.51
# Epoch 91, CIFAR-10 Batch 1:  Loss: 1.24
# Minibatch accuracy: 0.55
# Validation accuracy: 0.50
# Epoch 91, CIFAR-10 Batch 2:  Loss: 1.18
# Minibatch accuracy: 0.68
# Validation accuracy: 0.49
# Epoch 91, CIFAR-10 Batch 3:  Loss: 1.11
# Minibatch accuracy: 0.68
# Validation accuracy: 0.51
# Epoch 91, CIFAR-10 Batch 4:  Loss: 1.05
# Minibatch accuracy: 0.73
# Validation accuracy: 0.50
# Epoch 91, CIFAR-10 Batch 5:  Loss: 1.28
# Minibatch accuracy: 0.52
# Validation accuracy: 0.50
# Epoch 92, CIFAR-10 Batch 1:  Loss: 1.31
# Minibatch accuracy: 0.55
# Validation accuracy: 0.50
# Epoch 92, CIFAR-10 Batch 2:  Loss: 1.20
# Minibatch accuracy: 0.60
# Validation accuracy: 0.49
# Epoch 92, CIFAR-10 Batch 3:  Loss: 1.17
# Minibatch accuracy: 0.70
# Validation accuracy: 0.51
# Epoch 92, CIFAR-10 Batch 4:  Loss: 1.09
# Minibatch accuracy: 0.73
# Validation accuracy: 0.50
# Epoch 92, CIFAR-10 Batch 5:  Loss: 1.30
# Minibatch accuracy: 0.60
# Validation accuracy: 0.51
# Epoch 93, CIFAR-10 Batch 1:  Loss: 1.28
# Minibatch accuracy: 0.50
# Validation accuracy: 0.51
# Epoch 93, CIFAR-10 Batch 2:  Loss: 1.22
# Minibatch accuracy: 0.62
# Validation accuracy: 0.50
# Epoch 93, CIFAR-10 Batch 3:  Loss: 1.17
# Minibatch accuracy: 0.68
# Validation accuracy: 0.51
# Epoch 93, CIFAR-10 Batch 4:  Loss: 1.03
# Minibatch accuracy: 0.77
# Validation accuracy: 0.50
# Epoch 93, CIFAR-10 Batch 5:  Loss: 1.32
# Minibatch accuracy: 0.50
# Validation accuracy: 0.51
# Epoch 94, CIFAR-10 Batch 1:  Loss: 1.24
# Minibatch accuracy: 0.55
# Validation accuracy: 0.50
# Epoch 94, CIFAR-10 Batch 2:  Loss: 1.17
# Minibatch accuracy: 0.65
# Validation accuracy: 0.50
# Epoch 94, CIFAR-10 Batch 3:  Loss: 1.21
# Minibatch accuracy: 0.70
# Validation accuracy: 0.51
# Epoch 94, CIFAR-10 Batch 4:  Loss: 1.06
# Minibatch accuracy: 0.75
# Validation accuracy: 0.51
# Epoch 94, CIFAR-10 Batch 5:  Loss: 1.26
# Minibatch accuracy: 0.57
# Validation accuracy: 0.51
# Epoch 95, CIFAR-10 Batch 1:  Loss: 1.26
# Minibatch accuracy: 0.52
# Validation accuracy: 0.50
# Epoch 95, CIFAR-10 Batch 2:  Loss: 1.13
# Minibatch accuracy: 0.62
# Validation accuracy: 0.49
# Epoch 95, CIFAR-10 Batch 3:  Loss: 1.16
# Minibatch accuracy: 0.68
# Validation accuracy: 0.51
# Epoch 95, CIFAR-10 Batch 4:  Loss: 1.05
# Minibatch accuracy: 0.75
# Validation accuracy: 0.51
# Epoch 95, CIFAR-10 Batch 5:  Loss: 1.28
# Minibatch accuracy: 0.57
# Validation accuracy: 0.50
# Epoch 96, CIFAR-10 Batch 1:  Loss: 1.20
# Minibatch accuracy: 0.65
# Validation accuracy: 0.51
# Epoch 96, CIFAR-10 Batch 2:  Loss: 1.13
# Minibatch accuracy: 0.62
# Validation accuracy: 0.50
# Epoch 96, CIFAR-10 Batch 3:  Loss: 1.14
# Minibatch accuracy: 0.70
# Validation accuracy: 0.51
# Epoch 96, CIFAR-10 Batch 4:  Loss: 1.12
# Minibatch accuracy: 0.73
# Validation accuracy: 0.50
# Epoch 96, CIFAR-10 Batch 5:  Loss: 1.31
# Minibatch accuracy: 0.52
# Validation accuracy: 0.51
# Epoch 97, CIFAR-10 Batch 1:  Loss: 1.25
# Minibatch accuracy: 0.57
# Validation accuracy: 0.50
# Epoch 97, CIFAR-10 Batch 2:  Loss: 1.12
# Minibatch accuracy: 0.70
# Validation accuracy: 0.49
# Epoch 97, CIFAR-10 Batch 3:  Loss: 1.16
# Minibatch accuracy: 0.70
# Validation accuracy: 0.51
# Epoch 97, CIFAR-10 Batch 4:  Loss: 1.00
# Minibatch accuracy: 0.75
# Validation accuracy: 0.51
# Epoch 97, CIFAR-10 Batch 5:  Loss: 1.28
# Minibatch accuracy: 0.50
# Validation accuracy: 0.51
# Epoch 98, CIFAR-10 Batch 1:  Loss: 1.19
# Minibatch accuracy: 0.65
# Validation accuracy: 0.51
# Epoch 98, CIFAR-10 Batch 2:  Loss: 1.14
# Minibatch accuracy: 0.62
# Validation accuracy: 0.49
# Epoch 98, CIFAR-10 Batch 3:  Loss: 1.16
# Minibatch accuracy: 0.70
# Validation accuracy: 0.51
# Epoch 98, CIFAR-10 Batch 4:  Loss: 0.98
# Minibatch accuracy: 0.75
# Validation accuracy: 0.51
# Epoch 98, CIFAR-10 Batch 5:  Loss: 1.26
# Minibatch accuracy: 0.65
# Validation accuracy: 0.51
# Epoch 99, CIFAR-10 Batch 1:  Loss: 1.26
# Minibatch accuracy: 0.50
# Validation accuracy: 0.50
# Epoch 99, CIFAR-10 Batch 2:  Loss: 1.13
# Minibatch accuracy: 0.65
# Validation accuracy: 0.50
# Epoch 99, CIFAR-10 Batch 3:  Loss: 1.15
# Minibatch accuracy: 0.68
# Validation accuracy: 0.51
# Epoch 99, CIFAR-10 Batch 4:  Loss: 1.00
# Minibatch accuracy: 0.75
# Validation accuracy: 0.52
# Epoch 99, CIFAR-10 Batch 5:  Loss: 1.26
# Minibatch accuracy: 0.57
# Validation accuracy: 0.50
# Epoch 100, CIFAR-10 Batch 1:  Loss: 1.19
# Minibatch accuracy: 0.62
# Validation accuracy: 0.51
# Epoch 100, CIFAR-10 Batch 2:  Loss: 1.09
# Minibatch accuracy: 0.68
# Validation accuracy: 0.49
# Epoch 100, CIFAR-10 Batch 3:  Loss: 1.11
# Minibatch accuracy: 0.73
# Validation accuracy: 0.52
# Epoch 100, CIFAR-10 Batch 4:  Loss: 1.00
# Minibatch accuracy: 0.82
# Validation accuracy: 0.51
# Epoch 100, CIFAR-10 Batch 5:  Loss: 1.25
# Minibatch accuracy: 0.65
# Validation accuracy: 0.52

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as t
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.4984076433121019

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
